# %% [markdown]
# # 作業
# * 選擇迴歸資料集(右) - 交錯六群，在其他參數保持預設值的情況下，只允許調整隱藏層層數與神經元數量，且遵守下列限制
# > * 隱藏層神經元總數最多 8 個 (即 : 可以單層 8 個，或兩層 5 個與 3 個)
# > * 遞迴次數只允許跑到500次
# * 在上述限制下，挑戰看看測試誤差 (Test Loss) 最低能到多少? 請回答你的神經元參數與 Test Loss 數

# %% [markdown]
# Base - Hidden neuron: 0; Test Loss: 0.042

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Hidden neuron: 1; Test Loss: 0.041

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Hidden neuron: 2; Test Loss: 0.028

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Hidden neuron: 3; Test Loss: 0.023

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Hidden neuron: 4; Test Loss: 0.020

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Hidden neuron: 5; Test Loss: 0.019 (看起來在同一層繼續增加神經元已經沒有顯著降低誤差了)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Hidden neuron: 6(5 + 1); Test Loss: 0.018

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Hidden neuron: 7(5 + 2); Test Loss: 0.016

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Hidden neuron: 8(3 + 5); Test Loss: 0.015

# %% [markdown]
# ![image.png](attachment:image.png)
